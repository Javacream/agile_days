# %% [markdown]
# # Regressionsanalyse mit Python, Pandas und SciKit Learn

# %% [markdown]
# ## Vorkenntnisse
#
# * Grundlagen des Internets, sicherer Umgang mit dem Browser
# * Arbeiten mit CMD/Powershell/Bash
# * Grundlagen Python Programmierung
# * Grundlagen von Pandas

# %% [markdown]
# ## Inhalt
# * Einführung & Motivation
#   * Was ist lineare Regression?
#   * Mathematische Grundlagen
#   * Typische Anwendungsfälle
# * Pandas Rekapitulation
#   * Laden der Daten
#   * Exploration und Cleanup
#   * Plots
# * Lineare Regression mit scikit-learn
#   * Umsetzung einer Regression:
#   * Trainings- und Testdaten
#   * Modell trainieren
#   * Interpretation der Modellparameter
#   * Multiple lineare Regression
# * Modellbewertung
#   * Gütemaße, z.B. Mean Squared Error
#   * Overfitting vs. Underfitting
#   * Bedeutung von Train/Test-Split
#   * Korrelation vs. Kausalität

# %% [markdown]
# ## Ablauf

# %% [markdown]
# * Vorbereiten der Trainingsumgebung
#   * Laden Sie das GitHub-Repository und den Branch `python/data_analysis/regression`

# %%
# !git clone --branch data_analysis/regression --single-branch https://github.com/Javacream/agile_days.git

# %% [markdown]
# * Check
#   * Im Verzeichnis data_analysis/regression finden Sie die Datei mtcars.csv

# %% [markdown]
# * Bedeutung der Spalten
#   * model = Name
#   * mpg = Miles per Gallon
#   * cyl = Anzahl der Zylinder
#   * displacement = Hubraum
#   * hp = PS
#   * drat = Achsenübersetzung
#   * wt = Gewicht
#   * qsec = "Quarter Mile Time"
#   * vs = Motortyp, 0=V-Shaped, 1 = normal
#   * am = Gangschaltung, 0=automatisch, 1=manuell
#   * gear = Anzahl Gänge ohne Rückwärtsgang
#   * carb = Anzahl der Vergaser (= carburetors)

# %% [markdown]
# * Laden des Datensatzes mit Pandas
#   * Installieren Sie, falls notwendig, die Pandas-Bibliothek
#   * Erstellen Sie ein neues Jupyter Notebook und Laden den Datensatz
#   * Verifizieren Sie das korrekte Lesen der Daten
#   * Dauer: 15 min
#   * Hinweise
#     * Der Datensatz besteht aus 32 Zeilen mit 12 Spalten
#     * Alle Spalten außer `model` sind numerisch

# %% [markdown]
# * Exploration
#   * Prüfen Sie, ob NaN-Werte existieren
#   * Welche Spalten enthalten kategorische Daten?
#     * Hinweise
#       * Nutzen Sie hierzu die Methoden `unique` bzw. `nunique` des DataFrames
#       * Erzeugen Sie kategorische Spalten mit `pd.Category()`
#   * Verschaffen Sie sich eine Übersicht der verbliebenen Spalten mit kontinuierlichen Werten bezüglich der Verteilung der Daten
#     * Recherchieren Sie hierzu die Begriffe "Skewness" und "Kurtosis".
#     * Bestimmen Sie nun diese Werte und Beurteilen damit, ob Standard-Verfahren der deskriptiven Statistik angewendet werden dürfen
#   * Nutzen Sie Density-Plots, um die Daten zu Visualisieren und Vergleichen die Form mit einer Normalverteilung
#   * Dauer: 60 Minuten

# %% [markdown]
# * Deskriptive Statistik
#   * Bestimmen Sie nun typische Werte wie Mittelwert, Median, Standardabweichung und Percentilles
#   * Nutzen Sie Boxplots, zur Visualisierung
#   * Gruppieren Sie die Boxplots nach den gefundenen Kategorien
#   * Nutzen Sie das Notebook zur Präsentation Ihrer Erkenntnisse
#   * Dauer: 60 Minuten

# %% [markdown]
# * Korrelationen
#   * Nutzen Sie die Seaborn-Bibliothek, um einer Heatmap zu erstellen
#   * Optional: Seaborn Pairgrid mit Scatterplots
#   * Identifizieren Sie mindestens zwei Kandidaten, mit denen `mpg` korreliert sind
#   * Hinweis: Gewicht und Leistung sollten einen Einfluß haben
#   * Dauer: 45 Minuten

# %% [markdown]
# * Lineare Regression
#   * Installieren Sie das [SciKit Learn-Modul](https://scikit-learn.org/stable/)
#   * Importieren Sie nun die notwendigen Module, um eine Lineare Regression zwischen `mpg`und `weight` durchzuführen
#     * Hinweis
#       * Achsenabschnitt: 37.29
#       * Steigung: -5.34
#       * Score: 0.75
#   * Zeichnen Sie in den Scatterplot der Daten die Ausgleichsgerade
#   * Ist es plausibel, die Regression auch Effekte zweiter Ordnung zu berücksichtigen?
#     * Führen Sie diese Anlayse durch
#       * Hinweis
#         * Achsenabschnitt: 49.93
#         * Koeffizienten: [-13.38033708   1.17108689]
#         * Score: 0.82
#       * Zeichnen Sie auch hier die Kurve (eine Parabel) in den Scatterplot
#   * Wie ändert sich der Score, wenn Effekte beispielsweise bis zur 10. Ordnung berücksichtigt werden?
#     * Diskussion: Warum ist diese Analyse nicht zielführend?
#     * Zeichnen Sie auch hier die entstehene Kurve in einen Scatterplot und überzeugen Sie sich von der Absurdität des Ergebnisses
#   * Auch die Leistung `hp` sollte auf `mpg` einen Einfluss haben. Führen Sie eine analogen Analyse durch.
#   * Kombinieren Sie nun die Analyse mit `weight` und `hp`
#     * Hinweis: Eine Visualisierung der entstehenden Ausgleichsebene ist nicht notwendig
#     *  Gerne auch hier Effekte zweiter Ordnung berücksichtigen

# %% [markdown]
# * Story Telling
#   * Ergänzen Sie nun das Notebook, um die Ergebnisse in Ihren Worten zu präsentieren
#     * Vergessen Sie nicht, den Weg von der Korrelation zur Kausalität zu beschreiten

# %% [markdown]
# * Abschluss
#   * Nach dem Selbststudium erfolgt eine Besprechung einer möglichen Lösung
#   * Selbstverständlich können Sie diesen Teil auch nutzen, um Ihre Präsentation zu zeigen!

# %% [markdown]
# ## Ressourcen zum Selbststudium
#
# * [Notebook von Greg Hamel auf Kaggle](https://www.kaggle.com/code/hamelg/python-for-data-27-linear-regression)
# * [Zugehöriges Video auf YouTube](https://www.youtube.com/watch?v=O0HQnTJhr70&list=PLiC1doDIe9rCYWmH9wIEYEXXaJ4KAi3jc&index=27)
